# %% [markdown]
# <a href="https://colab.research.google.com/github/Surya20062425/sikit-learn/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install stable-baselines3 gymnasium
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.9.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.13/dist-packages (1.3.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.13/dist-packages (from stable-baselines3) (2.1.3)
# Requirement already satisfied: torch<3.0,>=2.8 in /usr/local/lib/python3.13/dist-packages (from stable-baselines3) (2.11.0+cpu)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.13/dist-packages (from stable-baselines3) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.13/dist-packages (from gymnasium) (4.16.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.13/dist-packages (from gymnasium) (0.0.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (3.32.5)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch<3.0,>=2.8->stable-baselines3) (2025.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.8->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch<3.0,>=2.8->stable-baselines3) (3.0.3)
# Downloading stable_baselines3-2.9.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 1.5 MB/s eta 0:00:00
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.9.0

# %%
import gymnasium as gym
from stable_baselines3 import PPO
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
env = gym.make("CartPole-v1")

# %%
model = PPO(
    policy="MlpPolicy",
    env=env,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=64,
    gamma=0.99,
    verbose=1
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
model.learn(total_timesteps=20000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | 20.4     |
# | time/              |          |
# |    fps             | 1149     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.5        |
# |    ep_rew_mean          | 24.5        |
# | time/                   |             |
# |    fps                  | 779         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009394998 |
# |    clip_fraction        | 0.0925      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00179    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.44        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 45.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.5        |
# |    ep_rew_mean          | 33.5        |
# | time/                   |             |
# |    fps                  | 726         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008669507 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0832      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 35.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.7        |
# |    ep_rew_mean          | 45.7        |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008991033 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.198       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 52.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.9        |
# |    ep_rew_mean          | 61.9        |
# | time/                   |             |
# |    fps                  | 721         |
# |    iterations           | 5           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008412328 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 59          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.5        |
# |    ep_rew_mean          | 76.5        |
# | time/                   |             |
# |    fps                  | 690         |
# |    iterations           | 6           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011854282 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.8        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 48.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.5         |
# |    ep_rew_mean          | 92.5         |
# | time/                   |              |
# |    fps                  | 681          |
# |    iterations           | 7            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0068177273 |
# |    clip_fraction        | 0.0674       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.593       |
# |    explained_variance   | 0.605        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.9         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.013       |
# |    value_loss           | 51.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 683         |
# |    iterations           | 8           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010573475 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.44        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 32.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 126         |
# |    ep_rew_mean          | 126         |
# | time/                   |             |
# |    fps                  | 684         |
# |    iterations           | 9           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009818903 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 37.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 10           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0062364247 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.74         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00786     |
# |    value_loss           | 55.8         |
# ------------------------------------------

# %%
model.save("ppo_cartpole")

# %%
model.save("ppo_cartpole")

# Test the Trained Agent
obs, info = env.reset()

for _ in range(500):

    action, _ = model.predict(obs, deterministic=True)

    obs, reward, terminated, truncated, info = env.step(action)

    done = terminated or truncated

    env.render()

    if done:
        obs, info = env.reset()

env.close()
print("Training Complete!")
# Out:
# /usr/local/lib/python3.13/dist-packages/gymnasium/envs/classic_control/cartpole.py:251: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(
# Training Complete!

# %%
model.save("ppo_cartpole")

# Test the Trained Agent
obs, info = env.reset()

for _ in range(500):

    action, _ = model.predict(obs, deterministic=True)

    obs, reward, terminated, truncated, info = env.step(action)

    done = terminated or truncated

    env.render()

    if done:
        obs, info = env.reset()

env.close()
print("Training Complete!")
# Out:
# Training Complete!
